# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("data/processed/DATA.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0   Timestamp  PM2.5 (µg/m³)  PM10 (µg/m³)  NO (µg/m³)  \
# 0           0  2020-01-01         392.31        450.67       84.61
# 1           1  2020-01-02         458.86        497.51       91.25
# 2           2  2020-01-03         198.92        219.98       93.91
# 3           3  2020-01-04         224.26        255.98       83.32
# 4           4  2020-01-05         149.03        172.24       36.83
#
#    NO2 (µg/m³)  NOx (ppb)  NH3 (µg/m³)  SO2 (µg/m³)  CO (mg/m³)  \
# 0        43.83      92.10        27.11        11.47        4.24
# 1        50.60     101.10        34.24        12.00        4.51
# 2        64.44     110.62        19.99         7.22        3.17
# 3        65.87     102.78        18.48         5.90        2.93
# 4        44.97      53.86        10.13         5.39        1.30
#
#    Ozone (µg/m³)  Benzene (µg/m³)  Leighton_ratio  VOC_NOx_ratio  O3_lag1  \
# 0          10.33             4.13       19.496348       0.044361      NaN
# ...

# %%
print(df.isna().sum())
# Out:
# Unnamed: 0         0
# Timestamp          0
# PM2.5 (µg/m³)      0
# PM10 (µg/m³)       0
# NO (µg/m³)         0
# NO2 (µg/m³)        0
# NOx (ppb)          0
# NH3 (µg/m³)        0
# SO2 (µg/m³)        0
# CO (mg/m³)         0
# Ozone (µg/m³)      0
# Benzene (µg/m³)    0
# Leighton_ratio     0
# VOC_NOx_ratio      0
# O3_lag1            1
# NOx_lag1           1
# dtype: int64

# %%
df = df.dropna()

# %%
return df
# Out:
#   Cell In[6], line 1
#     return df
#     ^
# SyntaxError: 'return' outside function

# %%
df.to_csv("data/processed/DATA.csv", index=False)
